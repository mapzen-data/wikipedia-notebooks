# %%
import networkx
import PageRank
import json
import operator
import sys
import glob
import os

# %%
sys.path.append("..")
from all_functions import *

# %%
path_to_json = '../PageRank_OUTPUT'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
Page_rank_dict={}
for js in json_files:
    with open(os.path.join(path_to_json, js)) as json_file:
        new_json=json.load(json_file)
    Page_rank_dict.update(new_json)

# %%
word_count_places = read_data('../Analyzed_data//final_titles_ids_all_status.csv')
places_population = read_data('../Analyzed_data//final_titles_ids_all_clean_population.csv')

# %%
places_population_1=places_population[['wof:id', '_population']]

# %%
word_count_places_pop = word_count_places.join(places_population_1.set_index(['wof:id']), on='wof:id', how = 'left')

# %%
word_count_places_clean=word_count_places[word_count_places['spell_check']=='OK']
key_set=set(Page_rank_dict.keys())

# %%
wordcount_pagerank=[]
for index, row in word_count_places_clean.iterrows():
    name = row['wk:page']
    if name in key_set:
        score = Page_rank_dict[name]
        row['Page_rank_score'] = score
    else:
        pass
    wordcount_pagerank.append(row)
    
df_wordcount_pagerank = pd.DataFrame(wordcount_pagerank)

# %%
df_wordcount_pagerank_pop = df_wordcount_pagerank.join(places_population_1.set_index(['wof:id']), on='wof:id', how = 'left')

# %%
df_wordcount_pagerank_1=df_wordcount_pagerank_pop[['wof:id','Page_rank_score','_population','wordcount' ]]

# %%
word_count_places_sorted = word_count_places_pop.sort('wordcount', ascending=False)
sorted_list = word_count_places_sorted[(word_count_places_sorted['spell_check']=='OK')&(word_count_places_sorted['placetype']=='locality')]
# Out:
# C:\Users\Olga\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
cities_unique = find_unique(sorted_list,'name')
data = range(len(cities_unique))
cities_unique['ran'] =data

# %%
NE_ranking = read_data('C:\Users\Olga\Documents\MAPZEN_data\Projects\Wiki\\NE_ranking.csv')

# %%
cities_unique_rank = []
for index, row in cities_unique.iterrows():
    if row['ran']<=9000:
        row['ranking_10'] = 1
    elif 9000<row['ran']<=18000:
        row['ranking_10'] = 2
    elif 18000<row['ran']<=27000:
        row['ranking_10'] = 3
    elif 27000<row['ran']<=36000:
        row['ranking_10'] = 4
    elif 36000<row['ran']<=45000:
        row['ranking_10'] = 5
    elif 45000<row['ran']<=54000:
        row['ranking_10'] = 6
    elif 54000<row['ran']<=63000:
        row['ranking_10'] = 7
    elif 63000<row['ran']<=72000:
        row['ranking_10'] = 8
    elif 72000<row['ran']<=81000:
        row['ranking_10'] = 9
    elif row['ran']>81000:
        row['ranking_10'] = 10
    cities_unique_rank.append(row)

# %%
cities_unique_rank_df=pd.DataFrame(cities_unique_rank)

# %%
cities_unique_rank_df_join=cities_unique_rank_df.join(NE_ranking.set_index(['NAME']), on='name', how='left')

# %%
cities_unique_rank_df_join_grouped = cities_unique_rank_df_join.groupby('ranking_10')

# %%
cities_unique_rank_df_join_grouped.get_group(3)
# Out:
#         Unnamed: 0                          name  \
# 168673        1132                       Rayland
# 168784        1256                     Willshire
# 247470         638                Breitengüßbach
# 249968        4008                        Ensign
# 37559         2217                 Varsity Lakes
# 205697         342                      Spearman
# 68992         2920                         Awasa
# 208062        2811  Mannersdorf am Leithagebirge
# 258328        3653                      St. Leon
# 219033        1467                          Ruby
# 257632        2926          San Mango sul Calore
# 201771        1177                Combined Locks
# 253533        3530                     Knebworth
# 202563        1972                         Kawit
# 27918         1733            Anglards-de-Salers
# 249437        3321                         Lewis
# 178353        1170                         Stacy
# 247111         149            Asnières-lès-Dijon
# 68501         2429                    Huamachuco
# 235216        4978                     Salamonia
# 183647        1614                         Nikel
# 199549        3827                        Bowler
# 219213        1667                    Urbisaglia
# 59570         1671                     Peschanka
# 255775         992                      Ringsted
# 198677        2937                     Scappoose
# 68257         2185         San Salvador de Jujuy
# 173378         972                    Liebenthal
# 216506        3136                   Larder Lake
# 187672         789                       Babinda
# ...            ...                           ...
# 177365         152                     Teaticket
# 171613        4182                    Hop Bottom
# 219296        1764                       Wiseman
# 191108        4256                   Nissequogue
# 52465         1601                       Cupuaçu
# 179530        2406                        Bambuí
# 168083         505                   Novyy Urgal
# 240410         802                        Karise
# 234589        4333                   Diemelstadt
# 168082         504                    Novy Urgal
# 190159        3298                      Doña Ana
# 190450        3590                 Walker Valley
# 38095         2753                  Mount Stuart
# 34981         3798                    Vergelegen
# 231778        1458                    Summertown
# 209063        3890                         Lasne
# 181453        4387                       Pachuta
# 216163        2689                     Maribojoc
# 219204        1656            West End-Cobb Town
# 191298        4447              West Glens Falls
# 159995        1215              Pecan Plantation
# 218067         246                   Vredenburgh
# 243927         369                     Włodowice
# 170961        3499                    Jerseytown
# 198465        2724                     Uncertain
# 172673         263                     Burrawang
# 245600        2877                         Detva
# 14347         4693                           Mar
# 249658        3615                   Glattfelden
# 62020          773                   Sam Roi Yot
#
#                                 wk:page     wd:id placetype spell_check  \
# 168673                    Rayland, Ohio       NaN  locality          OK
# 168784                  Willshire, Ohio       NaN  locality          OK
# 247470                   Breitengüßbach       NaN  locality          OK
# 249968                   Ensign, Kansas       NaN  locality          OK
# 37559         Varsity Lakes, Queensland  Q7916151  locality          OK
# 205697                  Spearman, Texas       NaN  locality          OK
# 68992                             Awasa   Q755765  locality          OK
# 208062     Mannersdorf am Leithagebirge       NaN  locality          OK
# 258328              Saint Leon, Indiana       NaN  locality          OK
# 219033                     Ruby, Alaska       NaN  locality          OK
# 257632             San Mango sul Calore       NaN  locality          OK
# 201771        Combined Locks, Wisconsin       NaN  locality          OK
# 253533                        Knebworth       NaN  locality          OK
# 202563                    Kawit, Cavite       NaN  locality          OK
# 27918                Anglards-de-Salers   Q799685  locality          OK
# 249437                    Lewis, Kansas       NaN  locality          OK
# 178353                 Stacy, Minnesota       NaN  locality          OK
# 247111               Asnières-lès-Dijon       NaN  locality          OK
# 68501                        Huamachuco  Q1632770  locality          OK
# 235216               Salamonia, Indiana       NaN  locality          OK
# 183647                            Nikel       NaN  locality          OK
# 199549                Bowler, Wisconsin       NaN  locality          OK
# 219213                       Urbisaglia       NaN  locality          OK
# 59570                         Peschanka  Q1168147  locality          OK
# 255775                   Ringsted, Iowa       NaN  locality          OK
# 198677                Scappoose, Oregon       NaN  locality          OK
# 68257             San Salvador de Jujuy    Q44217  locality          OK
# 173378               Liebenthal, Kansas       NaN  locality          OK
# 216506             Larder Lake, Ontario       NaN  locality          OK
# 187672                          Babinda       NaN  locality          OK
# ...                                 ...       ...       ...         ...
# 177365         Teaticket, Massachusetts       NaN  locality          OK
# 171613         Hop Bottom, Pennsylvania       NaN  locality          OK
# 219296                  Wiseman, Alaska       NaN  locality          OK
# 191108            Nissequogue, New York       NaN  locality          OK
# 52465                           Cupuaçu  Q1144414  locality          OK
# 179530                           Bambuí       NaN  locality          OK
# 168083                       Novy Urgal       NaN  locality          OK
# 240410                           Karise       NaN  locality          OK
# 234589                      Diemelstadt       NaN  locality          OK
# 168082                       Novy Urgal       NaN  locality          OK
# 190159             Doña Ana, New Mexico       NaN  locality          OK
# 190450          Walker Valley, New York       NaN  locality          OK
# 38095                      Mount Stuart  Q1493735  locality          OK
# 34981                        Vergelegen   Q787543  locality          OK
# 231778              Summertown, Georgia       NaN  locality          OK
# 209063                            Lasne       NaN  locality          OK
# 181453             Pachuta, Mississippi       NaN  locality          OK
# 216163                 Maribojoc, Bohol       NaN  locality          OK
# 219204      West End-Cobb Town, Alabama       NaN  locality          OK
# 191298       West Glens Falls, New York       NaN  locality          OK
# 159995          Pecan Plantation, Texas   Q970011  locality          OK
# 218067             Vredenburgh, Alabama       NaN  locality          OK
# 243927  Włodowice, Silesian Voivodeship       NaN  locality          OK
# 170961         Jerseytown, Pennsylvania       NaN  locality          OK
# 198465                 Uncertain, Texas       NaN  locality          OK
# 172673       Burrawang, New South Wales       NaN  locality          OK
# 245600                            Detva    Q11857  locality          OK
# 14347                               Mar  Q1308588  locality          OK
# 249658                      Glattfelden       NaN  locality          OK
# 62020              Sam Roi Yot District   Q476605  locality          OK
#
#            wof:id  wk_page_id  wordcount  _population    ran  ranking_10  \
# 168673  101713075         NaN        847          NaN  18001           3
# 168784  101713099         NaN        847          NaN  18002           3
# 247470  101825843         NaN        847          NaN  18003           3
# 249968   85945303         NaN        847          NaN  18004           3
# 37559   101935549         NaN        847          NaN  18005           3
# 205697  101724839         NaN        847          NaN  18006           3
# 68992   421189649         NaN        847          NaN  18007           3
# 208062  101785777         NaN        847          NaN  18008           3
# 258328   85942293         NaN        847          NaN  18009           3
# 219033   85915693         NaN        847          NaN  18010           3
# 257632  101856415         NaN        847          NaN  18011           3
# 201771  101732425         NaN        846          NaN  18012           3
# 253533  101853541         NaN        846          NaN  18013           3
# 202563  421167509         NaN        846          NaN  18014           3
# 27918   101894597         NaN        846          NaN  18015           3
# 249437   85945253         NaN        846          NaN  18016           3
# 178353   85952685         NaN        846          NaN  18017           3
# 247111  101889417         NaN        846          NaN  18018           3
# 68501   421186807         NaN        846          NaN  18019           3
# 235216   85941413         NaN        846          NaN  18020           3
# 183647  102001873         NaN        846          NaN  18021           3
# 199549  101733169         NaN        846          NaN  18022           3
# 219213  101798581         NaN        846          NaN  18023           3
# 59570   102014615         NaN        846          NaN  18024           3
# 255775   85943657         NaN        846          NaN  18025           3
# 198677  101715973         NaN        846          NaN  18026           3
# 68257   421185855         NaN        846          NaN  18027           3
# 173378   85946389         NaN        846          NaN  18028           3
# 216506  101735625         NaN        846          NaN  18029           3
# 187672  101933849         NaN        846          NaN  18030           3
# ...           ...         ...        ...          ...    ...         ...
# 177365   85950515         NaN        545          NaN  26971           3
# 171613  101717401         NaN        545          NaN  26972           3
# 219296   85916651         NaN        545          NaN  26973           3
# 191108   85978473         NaN        545          NaN  26974           3
# 52465   101983053         NaN        545          NaN  26975           3
# 179530  101948791         NaN        545          NaN  26976           3
# 168083  102015079         NaN        545          NaN  26977           3
# 240410  101818361         NaN        545          NaN  26978           3
# 234589  101810119         NaN        545          NaN  26979           3
# 168082  102015077         NaN        545          NaN  26980           3
# 190159   85977071         NaN        545          NaN  26981           3
# 190450   85978909         NaN        545          NaN  26982           3
# 38095   101938189         NaN        545          NaN  26983           3
# 34981   101923175         NaN        545          NaN  26984           3
# 231778   85936213         NaN        545          NaN  26985           3
# 209063  101755265         NaN        545          NaN  26986           3
# 181453   85970145         NaN        544          NaN  26987           3
# 216163  421198783         NaN        544          NaN  26988           3
# 219204   85915211         NaN        544          NaN  26989           3
# 191298   85980101         NaN        544          NaN  26990           3
# 159995  101726619         NaN        544          NaN  26991           3
# 218067   85913639         NaN        544          NaN  26992           3
# 243927  101823731         NaN        544          NaN  26993           3
# 170961  101720231         NaN        544          NaN  26994           3
# 198465  101725593         NaN        544          NaN  26995           3
# 172673  101929745         NaN        544          NaN  26996           3
# 245600  101843797         NaN        544          NaN  26997           3
# 14347   101831455         NaN        544          NaN  26998           3
# 249658  101854443         NaN        544          NaN  26999           3
# 62020   102024023         NaN        544          NaN  27000           3
#
#         SCALERANK  POP_MAX
# 168673        NaN      NaN
# 168784        NaN      NaN
# 247470        NaN      NaN
# 249968        NaN      NaN
# 37559         NaN      NaN
# 205697        NaN      NaN
# 68992           9   133097
# 208062        NaN      NaN
# 258328        NaN      NaN
# 219033        NaN      NaN
# 257632        NaN      NaN
# 201771        NaN      NaN
# 253533        NaN      NaN
# 202563        NaN      NaN
# 27918         NaN      NaN
# 249437        NaN      NaN
# 178353        NaN      NaN
# 247111        NaN      NaN
# 68501           8    30835
# 235216        NaN      NaN
# 183647          7    15866
# 199549        NaN      NaN
# 219213        NaN      NaN
# 59570         NaN      NaN
# 255775        NaN      NaN
# 198677        NaN      NaN
# 68257           6   305891
# 173378        NaN      NaN
# 216506        NaN      NaN
# 187672        NaN      NaN
# ...           ...      ...
# 177365        NaN      NaN
# 171613        NaN      NaN
# 219296          7       14
# 191108        NaN      NaN
# 52465         NaN      NaN
# 179530        NaN      NaN
# 168083        NaN      NaN
# 240410        NaN      NaN
# 234589        NaN      NaN
# 168082        NaN      NaN
# 190159        NaN      NaN
# 190450        NaN      NaN
# 38095         NaN      NaN
# 34981         NaN      NaN
# 231778        NaN      NaN
# 209063        NaN      NaN
# 181453        NaN      NaN
# 216163        NaN      NaN
# 219204        NaN      NaN
# 191298        NaN      NaN
# 159995        NaN      NaN
# 218067        NaN      NaN
# 243927        NaN      NaN
# 170961        NaN      NaN
# 198465        NaN      NaN
# 172673        NaN      NaN
# 245600        NaN      NaN
# 14347         NaN      NaN
# 249658        NaN      NaN
# 62020         NaN      NaN
#
# [9011 rows x 14 columns]
